# %%
import pandas as pd

# read ID as string, not int

sed_old = pd.read_csv('sed.tsv', sep='\t', dtype={'ID': str})
sed_new = pd.read_csv('Scrapers/sed.tsv', sep='\t', dtype={'ID': str})

# %%
# find the new rows
new_rows = sed_new[~sed_new['ID'].isin(sed_old['ID'])]
new_rows
# Out:
#           ID  PARAMETER_ID                                            CONCEPT  \
# 18419  27905           NaN      to weave; to respect; to assume, reckon, plan
# 18420  27904           NaN                               to consider, respect
# 18421  27903           NaN                                 to calculate, plan
# 18422  27906           NaN                (a) to count; (i) to think, believe
# 18423  27907           NaN                          to think, believe, esteem
# 18425  28057           NaN    hebes fuit (oculus); occaecatus est; occaecavit
# 18426  28058           NaN                        to be unable to see the sun
# 18427  24591           NaN                                      to be dazzled
# 18428  28056           NaN  to be dazzled; to have weak eyes, to be shorts...
# 18429   4108           NaN                                       shortsighted
#
#        DOCULECT     LANGUAGE_NAME  VALUE    FORM  TOKENS  GLOTTOLOG  LATITUDE  \
# ...
